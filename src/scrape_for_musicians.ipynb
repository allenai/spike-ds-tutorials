# %% [markdown]
# # Find Musicians
#
# The purpose of this code is to get a very long list of musicians. This list is later uploaded to SPIKE, so that we can find sentences that contain known musicians. This will be the basis for our test set.

# %%
import pandas
import requests
from bs4 import BeautifulSoup
from random import shuffle

# %% [markdown]
# Find a wikipedia page with a relevant list

# %%
wiki_url = "https://en.wikipedia.org/wiki/Lists_of_musicians"
response = requests.get(wiki_url)
soup = BeautifulSoup(response.content)

# %% [markdown]
# Note that the following code is tailored for the above wikipedia page. Error handling here is relaxed, since we are not trying to get an exhaustive list, but a very big sample.

# %%
musicians_by_category = dict()
general_list_of_musicians = []
for item in soup.find_all("li"):
    link = item.find("a")
    try:
        if link["href"].startswith("/wiki/List_of_"):
            musicians_by_category[link.text] = []
            sublist_url = f"https://en.wikipedia.org{link['href']}"
            sublist_response = requests.get(sublist_url)
            subsoup = BeautifulSoup(sublist_response.content)
            for artist in subsoup.find_all("li"):
                sublink = artist.find("a")
                if sublink:
                    if not sublink["href"].startswith("/wiki/List_of_"):
                        if not sublink.parent.get("class"):
                            if len(sublink.text) > 4:
                                musicians_by_category[link.text].append(sublink.text)
                                if all(x not in link.text for x in ["bands", "groups"] ):
                                    general_list_of_musicians.append(sublink.text)
                            if sublink.text == "^":
                                break
    except Exception as e:
        if link:
            print(link, e)
            
general_list_of_musicians[:10]
# Out:
# <a href="/wiki/List_of_anarcho-punk_bands" title="List of anarcho-punk bands">List of anarcho-punk bands</a> 'href'
# <a href="/wiki/List_of_bebop_musicians" title="List of bebop musicians">List of bebop musicians</a> 'href'
# <a href="/wiki/List_of_Christian_worship_music_artists" title="List of Christian worship music artists">List of Christian worship music artists</a> 'href'
# <a href="/wiki/List_of_cool_jazz_and_West_Coast_jazz_musicians" title="List of cool jazz and West Coast jazz musicians">List of cool jazz and West Coast jazz musicians</a> 'href'
# <a href="/wiki/List_of_dub_artists" title="List of dub artists">List of dub artists</a> 'href'
# <a href="/wiki/List_of_free_improvising_musicians_and_groups" title="List of free improvising musicians and groups">List of free improvising musicians and groups</a> 'href'
# <a href="/wiki/List_of_gospel_musicians" title="List of gospel musicians">List of gospel musicians</a> 'href'
# <a href="/wiki/List_of_punk_rock_bands,_L%E2%80%93Z" title="List of punk rock bands, L–Z">List of punk rock bands, L–Z</a> 'href'
# <a href="/wiki/List_of_1970s_punk_rock_musicians" title="List of 1970s punk rock musicians">List of 1970s punk rock musicians</a> 'href'
# <a href="/wiki/List_of_musicians_in_the_second_wave_of_punk_rock" title="List of musicians in the second wave of punk rock">List of musicians in the second wave of punk rock</a> 'href'
# <a href="/wiki/List_of_reggae_fusion_artists" title="List of reggae fusion artists">List of reggae fusion artists</a> 'href'
# <a href="/wiki/List_of_roots_reggae_artists" title="List of roots reggae artists">List of roots reggae artists</a> 'href'
# <a href="/wiki/List_of_scat_singers" title="List of scat singers">List of scat singers</a> 'href'
# <a href="/wiki/List_of_smooth_jazz_musicians" title="List of smooth jazz musicians">List of smooth jazz musicians</a> 'href'
# <a href="/wiki/List_of_UK_garage_artists" title="List of UK garage artists">List of UK garage artists</a> 'href'
# <a href="/wiki/List_of_classical_guitarists" title="List of classical guitarists">List of classical guitarists</a> 'href'
# <a href="/wiki/List_of_horn_players" title="List of horn players">List of horn players</a> 'href'
# <a href="/wiki/List_of_jazz_organists" title="List of jazz organists">List of jazz organists</a> 'href'
# <a href="/wiki/List_of_jazz_percussionists" title="List of jazz percussionists">List of jazz percussionists</a> 'href'
# <a href="/wiki/List_of_jazz_saxophonists" title="List of jazz saxophonists">List of jazz saxophonists</a> 'href'
# <a href="/wiki/List_of_trumpeters" title="List of trumpeters">List of trumpeters</a> 'href'
# <a href="/wiki/List_of_Ghanaian_musicians" title="List of Ghanaian musicians">List of Ghanaian musicians</a> 'href'
# <a href="/wiki/List_of_South_African_musicians" title="List of South African musicians">List of South African musicians</a> 'href'
# <a href="/wiki/List_of_Nigerian_musicians" title="List of Nigerian musicians">List of Nigerian musicians</a> 'href'
# <a href="/wiki/List_of_Ugandan_musicians" title="List of Ugandan musicians">List of Ugandan musicians</a> 'href'
# <a href="/wiki/List_of_Afghan_singers" title="List of Afghan singers">List of Afghan singers</a> 'href'
# <a href="/wiki/List_of_Afghan_singers" title="List of Afghan singers">List of Afghan singers</a> 'href'
# <a href="/wiki/List_of_Azerbaijani_composers" title="List of Azerbaijani composers">List of Azerbaijani composers</a> 'href'
# <a href="/wiki/List_of_Azerbaijani_composers" title="List of Azerbaijani composers">List of Azerbaijani composers</a> 'href'
# <a href="/wiki/List_of_Chinese_composers" title="List of Chinese composers">List of Chinese composers</a> 'href'
# <a href="/wiki/List_of_Chinese_composers" title="List of Chinese composers">List of Chinese composers</a> 'href'
# <a href="/wiki/List_of_Chinese_musicians" title="List of Chinese musicians">List of Chinese musicians</a> 'href'
# <a href="/wiki/List_of_Philippine-based_music_groups" title="List of Philippine-based music groups">List of Philippine-based music groups</a> 'href'
# <a href="/wiki/List_of_Philippine-based_music_groups" title="List of Philippine-based music groups">List of Philippine-based music groups</a> 'href'
# <a href="/wiki/List_of_Iranian_composers" title="List of Iranian composers">List of Iranian composers</a> 'href'
# <a href="/wiki/List_of_Iranian_composers" title="List of Iranian composers">List of Iranian composers</a> 'href'
# <a href="/wiki/List_of_Iranian_singers" title="List of Iranian singers">List of Iranian singers</a> 'href'
# <a href="/wiki/List_of_Israeli_classical_composers" title="List of Israeli classical composers">List of Israeli classical composers</a> 'href'
# <a href="/wiki/List_of_Israeli_classical_composers" title="List of Israeli classical composers">List of Israeli classical composers</a> 'href'
# <a href="/wiki/List_of_Israeli_musical_artists" title="List of Israeli musical artists">List of Israeli musical artists</a> 'href'
# <a href="/wiki/List_of_Indian_composers" title="List of Indian composers">List of Indian composers</a> 'href'
# <a href="/wiki/List_of_Indian_composers" title="List of Indian composers">List of Indian composers</a> 'href'
# <a href="/wiki/List_of_musical_artists_from_Japan" title="List of musical artists from Japan">List of Japanese musicians</a> 'href'
# <a href="/wiki/List_of_Japanese_hip_hop_musicians" title="List of Japanese hip hop musicians">List of Japanese hip hop musicians</a> 'href'
# <a href="/wiki/List_of_musical_artists_from_Japan" title="List of musical artists from Japan">List of musical artists from Japan</a> 'href'
# <a href="/wiki/List_of_Sri_Lankan_musicians" title="List of Sri Lankan musicians">List of Sri Lankan musicians</a> 'href'
# <a href="/wiki/List_of_Sri_Lankan_musicians" title="List of Sri Lankan musicians">List of Sri Lankan musicians</a> 'href'
# <a href="/wiki/List_of_Belarusian_musicians" title="List of Belarusian musicians">List of Belarusian musicians</a> 'href'
# <a href="/wiki/List_of_Belgian_bands_and_artists" title="List of Belgian bands and artists">List of Belgian bands and artists</a> 'href'
# <a href="/wiki/List_of_Belgian_bands_and_artists" title="List of Belgian bands and artists">List of Belgian bands and artists</a> 'href'
# <a href="/wiki/List_of_Scottish_musicians" title="List of Scottish musicians">List of Scottish musicians</a> 'href'
# <a href="/wiki/List_of_British_classical_composers" title="List of British classical composers">List of British classical composers</a> 'href'
# <a href="/wiki/List_of_punk_bands_from_the_United_Kingdom" title="List of punk bands from the United Kingdom">List of punk bands from the United Kingdom</a> 'href'
# <a href="/wiki/List_of_UK_garage_artists" title="List of UK garage artists">List of UK garage artists</a> 'href'
# <a href="/wiki/List_of_Bulgarian_musicians_and_singers" title="List of Bulgarian musicians and singers">List of Bulgarian musicians and singers</a> 'href'
# <a href="/wiki/List_of_Bulgarian_musicians_and_singers" title="List of Bulgarian musicians and singers">List of Bulgarian musicians and singers</a> 'href'
# <a href="/wiki/List_of_Danish_composers" title="List of Danish composers">List of Danish composers</a> 'href'
# <a href="/wiki/List_of_Danish_composers" title="List of Danish composers">List of Danish composers</a> 'href'
# <a href="/wiki/List_of_Danish_musicians" title="List of Danish musicians">List of Danish musicians</a> 'href'
# <a href="/wiki/List_of_Dutch_composers" title="List of Dutch composers">List of Dutch composers</a> 'href'
# <a href="/wiki/List_of_Dutch_composers" title="List of Dutch composers">List of Dutch composers</a> 'href'
# <a href="/wiki/List_of_Dutch_musicians" title="List of Dutch musicians">List of Dutch musicians</a> 'href'
# <a href="/wiki/List_of_Finnish_composers" title="List of Finnish composers">List of Finnish composers</a> 'href'
# <a href="/wiki/List_of_Finnish_musicians" title="List of Finnish musicians">List of Finnish musicians</a> 'href'
# <a href="/wiki/List_of_Finnish_singers" title="List of Finnish singers">List of Finnish singers</a> 'href'
# <a href="/wiki/List_of_French_composers" title="List of French composers">List of French composers</a> 'href'
# <a href="/wiki/List_of_French_composers" title="List of French composers">List of French composers</a> 'href'
# <a href="/wiki/List_of_French_singers" title="List of French singers">List of French singers</a> 'href'
# <a href="/wiki/List_of_German_musicians" title="List of German musicians">List of German musicians</a> 'href'
# <a href="/wiki/List_of_Greek_composers" title="List of Greek composers">List of Greek composers</a> 'href'
# <a href="/wiki/List_of_Greek_composers" title="List of Greek composers">List of Greek composers</a> 'href'
# <a href="/wiki/List_of_Polish_musicians_and_musical_groups" title="List of Polish musicians and musical groups">List of Polish musicians and musical groups</a> 'href'
# <a href="/wiki/List_of_Polish_musicians_and_musical_groups" title="List of Polish musicians and musical groups">List of Polish musicians and musical groups</a> 'href'
# <a href="/wiki/List_of_Portuguese_musicians" title="List of Portuguese musicians">List of Portuguese musicians</a> 'href'
# <a href="/wiki/List_of_Portuguese_musicians" title="List of Portuguese musicians">List of Portuguese musicians</a> 'href'
# <a href="/wiki/List_of_Portuguese_singers" title="List of Portuguese singers">List of Portuguese singers</a> 'href'
# <a href="/wiki/List_of_Romanian_composers" title="List of Romanian composers">List of Romanian composers</a> 'href'
# <a href="/wiki/List_of_Romanian_composers" title="List of Romanian composers">List of Romanian composers</a> 'href'
# <a href="/wiki/List_of_Romanian_musicians" title="List of Romanian musicians">List of Romanian musicians</a> 'href'
# <a href="/wiki/List_of_Romanian_singers" title="List of Romanian singers">List of Romanian singers</a> 'href'
# <a href="/wiki/List_of_Russian_composers" title="List of Russian composers">List of Russian composers</a> 'href'
# <a href="/wiki/List_of_Russian_composers" title="List of Russian composers">List of Russian composers</a> 'href'
# <a href="/wiki/List_of_Russian_opera_singers" title="List of Russian opera singers">List of Russian opera singers</a> 'href'
# <a href="/wiki/List_of_Serbian_musicians" title="List of Serbian musicians">List of Serbian musicians</a> 'href'
# <a href="/wiki/List_of_Serbian_musicians" title="List of Serbian musicians">List of Serbian musicians</a> 'href'
# <a href="/wiki/List_of_Slovenian_musicians" title="List of Slovenian musicians">List of Slovenian musicians</a> 'href'
# <a href="/wiki/List_of_Slovenian_musicians" title="List of Slovenian musicians">List of Slovenian musicians</a> 'href'
# <a href="/wiki/List_of_Spanish_musicians" title="List of Spanish musicians">List of Spanish musicians</a> 'href'
# <a href="/wiki/List_of_Swedes_in_music" title="List of Swedes in music">List of Swedes in music</a> 'href'
# <a class="mw-redirect" href="/wiki/List_of_American_folk_musicians_in_Washington" title="List of American folk musicians in Washington">List of American folk musicians in Washington</a> 'href'
# <a href="/wiki/List_of_The_Minus_5_members" title="List of The Minus 5 members">List of The Minus 5 members</a> 'href'
# <a href="/wiki/List_of_Canadian_composers" title="List of Canadian composers">List of Canadian composers</a> 'href'
# <a href="/wiki/List_of_Canadian_musicians" title="List of Canadian musicians">List of Canadian musicians</a> 'href'
# <a href="/wiki/List_of_bands_from_British_Columbia" title="List of bands from British Columbia">List of bands from British Columbia</a> 'href'
# <a href="/wiki/List_of_bands_from_British_Columbia" title="List of bands from British Columbia">List of bands from British Columbia</a> 'href'
# <a href="/wiki/List_of_bands_from_British_Columbia" title="List of bands from British Columbia">List of bands from British Columbia</a> 'href'
# <a href="/wiki/List_of_musicians_from_British_Columbia" title="List of musicians from British Columbia">List of musicians from British Columbia</a> 'href'
# <a href="/wiki/List_of_Montreal_music_groups" title="List of Montreal music groups">List of Montreal music groups</a> 'href'
# <a href="/wiki/List_of_musicians_from_Quebec" title="List of musicians from Quebec">List of musicians from Quebec</a> 'href'
# <a href="/wiki/List_of_Brazilian_composers" title="List of Brazilian composers">List of Brazilian composers</a> 'href'
# <a href="/wiki/List_of_Brazilian_composers" title="List of Brazilian composers">List of Brazilian composers</a> 'href'
# <a href="/wiki/List_of_Brazilian_musicians" title="List of Brazilian musicians">List of Brazilian musicians</a> 'href'
# <a href="/wiki/List_of_anarchist_musicians" title="List of anarchist musicians">List of anarchist musicians</a> 'href'
# ['2nd Chapter of Acts',
#  'After the Fire',
#  'Dennis Agajanian',
#  'All Saved Freak Band',
#  'The Alpha Band',
#  'The Archers',
#  'a band called David',
#  'Brown Bannister',
#  'Bash-n-the-Code',
#  'Bob Bennett']

# %%
# Create a file with one item per line. This should later be manually cleaned, or take a clean sample from this list.
with open("../data/lists/musicians_dirty.txt", "w") as f:
    shuffle(general_list_of_musicians) # avoid having all musicians from related genres. 
    for x in general_list_of_musicians:
        f.write(f"{x}\n")

# %% [markdown]
# ### scrape for comedians
#
# Another example. This can, but doesn't have to, be a part of collecting negative examples.

# %%
wiki_url = "https://en.wikipedia.org/wiki/List_of_comedians"
response = requests.get(wiki_url)
soup = BeautifulSoup(response.content)

# %%
with open("../data/lists/comedians_dirty.txt", "w") as f:
    for item in soup.find_all("li"):
        try:
            link = item.find("a")
            if link["href"].startswith("/wiki/"):
                if len(link.text.split()) > 1:
                    f.write(link.text + "\n")
        except:
            print(link)
# Out:
# None
# None
