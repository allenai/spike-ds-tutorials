# %%
unique_captures = "--unique_captures"
distractor = "--distractor GPE"
suffix = "--suffix _py"
version_name = "--version_name py_scripts"
wandb_project = "--wandb_project pyscripts"
experiment_suffix = "--experiment_suffix manual"
superclass_tag = "--superclass_tag PER"
target_tag = "--target_tag MUS"
patterns_file = "--patterns_file ../src/patterns_hearst.json"

# %%
# !python ../src/get_pattern_matches.py {unique_captures} {distractor} {suffix} {superclass_tag} {patterns_file}
# Out:
# ...
# 100%|███████████████████████████████████████████| 10/10 [00:39<00:00,  3.97s/it]
# number of matches for pattern 111: 4000
# number of matches for pattern 222: 4000
# number of matches for pattern 333: 4000

# %%
# !pwd
# Out:
# /home/shoval/side-projects/spike-ds-tutorials/notebooks

# %%
# %%bash -s "$suffix" "$version_name" "$superclass_tag" "$target_tag"
# python dataset_creation.py $1 $2 $3 $4

# %%
# %%bash -s "$wandb_project" "$experiment_suffix" "$suffix" "$version_name"  "$superclass_tag" "$target_tag"
# python train_with_simpletransformers.py $1 $2 $3 $4 $5 $6
