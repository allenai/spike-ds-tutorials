# %%
unique_captures = "--unique_captures"
distractor = "--distractor PERSON"
suffix = "--suffix _sch"
version_name = "--version_name py_scripts"
wandb_project = "--wandb_project pyscripts"
experiment_suffix = "--experiment_suffix only-hearst"
superclass_tag = "--superclass_tag ORG"
target_tag = "--target_tag SCH"
patterns_file = "--patterns_file ../src/school_patterns.json"
dataset_name = "--dataset_name schools"
hearst_patterns = "--hearst_patterns ../src/school_hearst.json"
hearst_limit = "--hearst_limit 10000"
dataset_path= f'--dataset_path ../data/schools'

# %%
# !mkdir -p ../data/schools

# %%
# !mkdir ../data/spike_matches/hearst/

# %%
# !python ../src/get_pattern_matches.py {unique_captures} {distractor} {suffix} {superclass_tag} {patterns_file} {hearst_patterns} {hearst_patterns}

# %%
# !wc -l ../data/spike_matches/positive/*

# %%
# !python ../src/dataset_creation.py {suffix} {version_name} {superclass_tag} {target_tag} {dataset_name}

# %%
# !wc -l ../data/schools/*

# %%
# !python ../src/train_with_simpletransformers.py {wandb_project} {experiment_suffix} {suffix} {version_name}  {superclass_tag} {target_tag} {dataset_path}
